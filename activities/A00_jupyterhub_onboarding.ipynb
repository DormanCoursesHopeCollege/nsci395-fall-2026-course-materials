# %% [markdown]
# # A00: Course orientation and access check
#
# Today is not a coding lesson. We will use the first meeting to meet one another, discuss what computational neuroscience can contribute, review how the course will work, and confirm that everyone can reach the required systems.
#
# By the end of class, you should be able to:
#
# 1. describe one question that computation could help address in neuroscience;
# 2. identify the main course routines and sources of support;
# 3. open JupyterHub, select the course kernel, run a cell, find the course files, and reach the course GitHub resources.

# %% [markdown]
# ## About me
#
# - Daniel Dorman (he/him/his), PhD in Neuroscience
# - You can call me Dr. Dorman, Professor Dorman, Professor, Dorman…
# - I teach courses in the neuroscience program and conduct computational and experimental neurophysiology research
# - Office: SC3029a (Come into the lab and around the corner to find my office/see if I’m in)
# - Office hours: feel free to drop in, or [schedule an appointment here](https://calendar.app.google/MTtJzPzfm6kC7M1a9)
# - Why computational neuroscience?

# %% [markdown]
# ## What brain region are you?
# [Complete this Buzzfeed quiz](https://www.buzzfeed.com/amygdala103/what-part-of-the-brain-are-you-cd0okrod4x)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Introductions
#
# Meet with one or two classmates. Take turns sharing:
#
# - what brain region you are;
# - your name, major or program, and year;
# - what coding experience, if any, you have had;
# - one thing that would help you feel comfortable learning computation in this class.

# %% [markdown]
# ## Big-picture discussion
#
# Write briefly on your own, then discuss with your group.
#
# - What does "computational neuroscience" mean to you?
#
# As a group:
# - Come up with a "sci-fi" futuristic/technology idea (can be dystopian or utopian) involving computatiional neuroscience

# %% [markdown]
# ## Some "Big Question" Quotes

# %% [markdown]
# ### Ray Kurzweil, *The Singularity is Near: When Humans Transcend Biology*
#
# “Our human intelligence is based on computational processes that we are learning to understand. We will ultimately multiply our intellectual powers by applying and extending the methods of human intelligence using the vastly greater capacity of nonbiological computation.”

# %% [markdown]
# ### Bancroft, *Ethical Aspects of Computational Neuroscience, Neuroethics*, 2013
#
# “’Can a computational simulation of a brain suffer?’. If the answer is ‘yes’, it then follows that we should consider extending the same protections against suffering that are given to subjects of experimental research.”

# %% [markdown]
# ### Marilynne Robinson, “Experience”, *The Givenness of Things*
#
# “Here is an idea that would make Descartes blanch. Apparently, there are scientists who believe that at some point fairly soon we will be able to upload our minds to computers, freeing ourselves from our bodies, being, therefore, immortal. I suppose they will program in the virtual experience of taking the uploaded dog on a walk to the virtual park, through the rain on randomly assorted virtual days adjusted to reflect prevailing weather patterns in some selected place and season. These immortals would at last be free of the thousand natural shocks that flesh is heir to, and with them no doubt of all urgent reflection on what we are and what we mean….
#
# I can’t help imagining that, given the sterility of it all, the sullens would set in and these uploaded minds would do what many of their creators do—devise ingenious viruses, spy on one another, refine resentments, contrive schemes to dupe the mortals. Then physical reality, let us say a great solar storm, the impact of a meteor, even a major war, would sweep them all away, making the always necessary point that, for our purposes, the physical is not to be transcended. In any case, an uploaded mind would be as void of soul as a cryogenically frozen body. We know this intuitively.”

# %% [markdown]
# ## Big Questions Discussion
#
# - Are these ideas feasibly grounded in computational neuroscience?
# - What insights does computational neuroscience have to offer to our understanding of brain, mind, and, as Christians, the soul?

# %% [markdown]
# ## What "Computational Neuroscience" means to me
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## The course in one cell
#
# The course will repeatedly use the same basic pattern:
#
# **read a small example, predict, run, explain, change, check, and apply**
#
# We will begin with a small Python toolkit, then use it to simulate membrane voltage and spiking neurons, analyze real public spike data, study simple circuits and population activity, and complete a bounded team project. Most class meetings use a notebook rather than slides. Fridays often emphasize practice, debugging, explanation, or project work.

# %% [markdown]
# ## Syllabus check
#
# [Syllabus Google Docs Link](https://docs.google.com/document/d/1Qjd-oPku12o2l5QR2jyVbHRPzBbLuSzSfzzunYDk8HI/edit?usp=sharing)
#
# Use the syllabus to find clear answers to these questions. Ask about anything that remains unclear.
#
# - What prior coding or mathematics is required?
# - What kinds of work make up the course grade?
# - What is the role of pair work?
# - What kinds of AI or code assistance are allowed?
# - What should you do when code does not work?

# %% [markdown]
# ## JupyterHub access check
#
# Complete each step. Do not spend the whole class silently troubleshooting. If a step fails, note the problem and ask for help.
#
# 1. Sign in to the course JupyterHub with your Hope account: [nsci395.danielbdorman.com](https://nsci395.danielbdorman.com)
# 2. Locate this notebook in the course-materials folder.
# 3. Confirm that this notebook opens in JupyterLab.
# 4. Confirm that the selected kernel is **Python — NSCI 395**.
# 5. Run the next two cells.

# %%
print('Hello, world')
print('My NSCI 395 course kernel is working.')

# %%
# This cell only confirms which Python environment is running.
# You are not expected to understand these lines today.
import sys
print('Python version:', sys.version.split()[0])
print('Kernel executable:', sys.executable)

# %% [markdown]
# ## Course-files check
#
# In the course-materials folder, find and open each of the following:
#
# - `README.md`;
# - `syllabus/README.md`, which links to the syllabus and schedule;
# - the `activities` folder;
# - the `resources` folder.
#
# Open the syllabus link and confirm it loads with your Hope account. Then open
# `resources/PYTHON_QUICK_REFERENCE.md` and keep the tab. You will use it all
# semester.
#
# The `notebooks` folder is not there yet. The first coding notebook, P00, is
# released before Wednesday, and it will appear in this same folder without
# disturbing anything you have saved.

# %% [markdown]
# ## GitHub access check
#
# 1. Sign in to GitHub.
# 2. Open the course repository link: https://github.com/DormanCoursesHopeCollege/nsci395-fall-2026-course-materials
# 3. Confirm that you can see the central course-materials repository.
#
# Today we are only confirming access. We will practice the small save, commit, push, and verify routine on Friday, September 11, before the first assignment is due.

# %% [markdown]
# ## Exit check
#
# Before leaving, confirm or report the status of each item:
#
# - JupyterHub login;
# - **Python — NSCI 395** kernel;
# - successful `Hello, world` output;
# - course files;
# - GitHub account and course repository access.
#
# Submit one question you still have about the course and note any access problem that remains.
#
# Don't forget to submit your student info form if you haven't yet!
# https://forms.gle/5QHmtGnQ7CnsBU5n7

# %% [markdown]
# ## Extra Discussion Questions (if time allows)
#
# 1. What is one question about a neuron, circuit, behavior, or neural dataset that would be hard to answer by observation alone?
# 2. What might a computational model or analysis add?
# 3. Can a simplified model be useful even when it leaves out most biological detail? Give an example or a reason.
# 4. What would make you trust, or distrust, a result produced by code?
